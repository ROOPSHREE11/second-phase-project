# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10,7)
plt.rcParams['figure.facecolor'] = 'FFE584'

# %%
data = pd.read_csv(r'C:\Users\ROOPSHREE\Downloads\happiness_score_dataset.csv')

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.shape
# Out:
# (158, 12)

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# univariate analysis

# %%
happiness_score = data['Happiness Score']

sns.kdeplot(happiness_score,shade = True, color = 'skyblue')
plt.xlabel('Happiness Score')
plt.ylabel('Density')
plt.title('Kernel Density Plot Of Happiness Score')
plt.show()
# Out:
# C:\Users\ROOPSHREE\AppData\Local\Temp\ipykernel_14940\338906131.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(happiness_score,shade = True, color = 'skyblue')

# %% [markdown]
# counting countries on basis of region

# %%
def plot_columnwise(data,nGraphShown,nGraphPerRow):
    nunique = data.nunique()
    data = data[(col for col in data if nunique[col] > 1 and nunique[col]< 50)]
    nRow, nCol = data.shape
    columnNames = list[data]
    nGraphRow = (ncol + nGraphPerRow -1) // nGraphPerRow
    plt.figure(num = None, figsize = (6*nGraphPerRow,8*nGraphRow),dpi = 80 ,facecolor = 'w',edgecolor = 'k')
    for i in range(min(ncol,nGraphShown)):
        plt.subplot(nGraphRow,nGraphPerRow,i+1)
        columnof = data.iloc[: , i]
        if (not np.issubdtype(type(columnDATA.iloc[0]),np.number)):
            valuecounts = columnDATA.value_counts()
            valuecounts.plot.bar()
        else:
            columnDATA.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]}(column{i})')
    plt.tight_layout(pad = 1.0,w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
correlation_matrix=data.corr()

plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot= True, cmap = 'coolwarm',linewidth= 0.5)
plt.title('correlation_matrix of the World Happiness Report 2016')
plt.show()
# Out:
# C:\Users\ROOPSHREE\AppData\Local\Temp\ipykernel_14940\4166696440.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=data.corr()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
le =  LabelEncoder()
data['Region']=le.fit_transform(data['Region'])
data['Country']=le.fit_transform(data['Country'])
data.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %% [markdown]
# Removing Outliers

# %%
for i in data.columns:
    data[[i]].boxplot()
    plt.show()

# %%
from scipy import stats
z_thresold = 3
z_scores = stats.zscore(data.select_dtypes(include='number'))

outliers = (z_scores > z_thresold).any(axis = 1)

cleaned_data = data[~outliers]
data.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %% [markdown]
# Making ML model

# %%
x=data.drop('Happiness Score', axis=1)
y=data['Happiness Score']
x.head()
# Out:
#    Country  Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0      135       9               1         0.03411                   1.39651
# 1       58       9               2         0.04884                   1.30232
# 2       37       9               3         0.03328                   1.32548
# 3      105       9               4         0.03880                   1.45900
# 4       24       5               5         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
